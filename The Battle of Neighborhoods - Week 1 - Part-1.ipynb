# %% [markdown]
# # The Battle of the Neighborhoods - Week 1

# %% [markdown]
# ## Introduction:

# %% [markdown]
# ## Problem Background:

# %% [markdown]
# It is well known that the city of New York in the United States is one of the most iconic city par excellence of this country and in the world. Its multiculturalism and cosmopolitan nature make this place a wonderful source of opportunities, both for life quality and social, and for economic development. It has become the international center for business and commerce due to Wall Street and the financial market that this entails. Both the retail trade, as well as the industries related to tourism, art and fashion, and the various items have an epicenter here.
#
# This leads to extreme competition in the market. Being a city with an advanced development in all its areas, the cost of doing business is also one of the highest on the planet. Therefore, any type of investment or business development plan must be analyzed carefully. From this report, the analysis and conclusions, will give good understanding of the business environment which help in strategically targeting the market. In this way, the investment risk will be reduced and will be beneficial for any company.

# %% [markdown]
# ## Problem Description:

# %% [markdown]
# The City of New York is famous for its excelllent cuisine. The mix between world famous restaurants, and respected chefs around the world and immigrants of different nationalities who live in this city, make this place a unique space.
# To understand a little more about multiculturalism, it is good to highlight some points of the strongest cultures that coexist there:
#
# - Italian immigrants, and with them their New York-style pizzas and all Italian cuisine (pastas, wines, etc.).
# - European immigrants, especially Jews, and their typical dishes.
# - Irish and Scottish immigrants: meat fanatics in conservation and beer.
# - Asian immigrants: Chinese and Japanese mostly making themselves present in almost every corner of the city with its millenary culture.
# - Immigrants from the Middle East. Turks and other citizens from all sides.
# - Food trucks: Approximately 5,000 licensed to work in the city.
#
# So it is evident that to survive in such competitive market it is very important to startegically plan. Various factors need to be studied inorder to decide on the Location such as:
#
# - New York Population
# - New York City Demographics
# - Are there any Farmers Markets, Wholesale markets etc nearby so that the ingredients can be purchased fresh to maintain quality and cost?
# - Are there any venues like Gyms, Entertainmnet zones, Parks etc nearby where floating population is high etc
# - Who are the competitors in that location?
# - Cuisine served / Menu of the competitors
# - Segmentation of the Borough
# - Untapped markets
# - Saturated markets

# %% [markdown]
# The company that we are helpint in this case has the necessary resources so, after correctly choosing its location, it can start its operations, and if successful, replicate the formula elsewhere.

# %% [markdown]
# ## Target Audience:

# %% [markdown]
# To recommend the correct location, the company has appointed me to lead of the Data Science team. The objective is to locate and recommend to the management which neighborhood of Newyork city will be best choice to start a restaurant. The Management also expects to understand the rationale of the recommendations made.
#
# This would interest anyone who wants to start a new restaurant in Newyork city.

# %% [markdown]
# ## Success Criteria:

# %% [markdown]
# The success criteria of the project will be a good recommendation of borough/Neighborhood choice to the company based on Lack of such restaurants in that location and nearest suppliers of ingredients.
